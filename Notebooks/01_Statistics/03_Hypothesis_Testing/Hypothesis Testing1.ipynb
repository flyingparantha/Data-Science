# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# # Motivation
#
# The purpose of hypothesis testing is to determine whether
# there is enough statistical evidence in favor of a certain
# belief, or hypothesis, about a parameter.
#
# **1.** Is there statistical evidence, from a random sample of
# potential customers, to support the hypothesis that
# more than 10% of the potential customers will purchase a new product?
#
# **2.** Is a new drug effective in curing a certain disease? A
# sample of patients is randomly selected. Half of them
# are given the drug while the other half are given a
# placebo. The conditions of the patients are then measured and compared.
#
# **3.** Suppose an economist wants to determine whether the monthly energy cost for families has changed from the previous year, when the mean cost per month was **$260**. The economist randomly samples 25 families and records their energy costs for the current year.

# %% [markdown]
# ## Null and alternative hypothesis
#
# **Null hypothesis(H0)** : A type of hypothesis used in statistics that proposes that there is no difference between certain characteristics of a population.
#
# **Alternative hypothesis(H1 or HA)** : The alternative hypothesis proposes that there is a difference. It is the alternative of null hypothesis.
#
# H0 : X1=X2
#
# H1 : X1>X2
#
# H1 : X1<X2
#
# H1 : X1≠X2
#
#
#
# **Some examples to have a better understanding of null and alternative hypothesis**
#
# **1.** We want to test whether the mean GPA of students in American colleges is different from 2.0 (out of 4.0). The null and alternative hypotheses are:
#
# **H0:** μ = 2.0
#
# **H1:** μ ≠ 2.0
#
# **2.** According to Glassdoor (the popular salary information website), the mean data scientist salary in the US is 11,000 dollars.
#
# **H0:** μ = $ 11,000
#
# **H1:** μ ≠ $ 11,000
#
# **3.** The average hours of sleeping are more than 8.
#
# **H0:** μ >  8 hours
#
# **H1:** μ <= 8 hours
#
# **4.** The mean birth weight of babies of Indian heritage is less than or equal to 3.5 kg
#
# **H0:** μ <= 3.5 kg
#
# **H1:** μ >  3.5 kg

# %% [markdown]
# # Types of errors
#
# Consider a person on trial for a **“criminal”** offense in the
# United States. Under the US system a jury (or sometimes
# just the judge) must decide if the person is innocent or
# guilty while in fact the person may be innocent or guilty.
# These combinations are summarized in the table below.
#
# **H0** : The person is innocent.
#
# **H1** : The person is guilty.

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=749x205 at 0x22DE0089CC0>

# %% [markdown]
# In a criminal trial, there actually is a favored assumption, an initial bias if you will. The jury is instructed to
# assume the person is innocent, and only decide that the
# person is guilty if the evidence convinces them of such.
# When there is a favored assumption, the presumed innocence of the person in this case, and the assumption is
# true, but the jury decides it is false and declares that the
# person is guilty, we have a so-called **Type I error**.
# Conversely, if the favored assumption is false, i.e., the
# person is really guilty, but the jury declares that it is
# true, that is that the person is innocent, then we have a
# so-called **Type II error**.
#
# **So now let us define our errors :**
#
# **Type I error** : The rejection of null hypothesis when it is true is known as type I error or false positive.
#
# **Type II error**: The acceptance of null hypothesis when it is false is known as type II error or false negative.
#
# **P(Type I Error)**
# = P(Jury Decides Guilty | Person is Innocent )= **α(level of significance**)
#
# **P(Type II Error)**
# = P(Jury Decides Innocent | Person is Guilty )=**β**

# %% [markdown]
# ## Note :
#
# Are both of these errors equally important? Or, is it as bad to decide
# that a guilty person is innocent and let them go free as
# it is to decide an innocent person is guilty and punish
# them for the crime?
# Speaking in terms of hypothesis language one of the important step is to decide which error should one minimize as there is a tradeoff between Type I and Type II errors.
# **Also note that you cannot minimize both th errors at the same time.**
#
# The go-to example to help people think about this is a defendant accused of a crime that demands an extremely harsh sentence.
#
# The null hypothesis is that the defendant is innocent. Of course you wouldn't want to let a guilty person off the hook, but most people would say that sentencing an innocent person to such punishment is a worse consequence.
#
# Hence, many textbooks and instructors will say that the Type 1 (false positive) is worse than a Type 2 (false negative) error. The rationale boils down to the idea that if you stick to the status quo or default assumption, at least you're not making things worse.
#
# Since there's not a clear rule of thumb about whether Type 1 or Type 2 errors are worse, our best option when using data to test a hypothesis is to look very carefully at the fallout that might follow both kinds of errors.

# %%
im2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1040x351 at 0x22DE02534E0>

# %% [markdown]
# ## Conclusion :
#
# Whatever your analysis involves, understanding the difference between Type 1 and Type 2 errors, and considering and mitigating their respective risks as appropriate, is always wise. For each type of error, make sure you've answered this question: "What's the worst that could happen?"
#
# **Generally we fix our α and try to minimize β since β is related to power of a test. However this might change according to the consequences of the errors in an experiment.**

# %% [markdown]
# ## Power and effect size
#
# **One of the most important question is - How much data do you need?**
#
# To make sound decisions based on statistical analysis, you need to be sure you can trust your results. We can measure this using statistical power—the likelihood that your test will identify a significant difference or effect when one truly exists. The statistical power you need varies based on your goals and your resources. Testing critical **airplane parts**, for example, demands a higher degree of certainty than **testing DVD players** and hence the data required will also be different.
#
#
#
#
# ## Effect Size :
#
#
# **Effect size is a statistical concept that measures the strength of the relationship between two variables on a numeric scale.  For instance, if we have data on the height of men and women and we notice that, on average, men are taller than women, the difference between the height of men and the height of women is known as the effect size.**  The greater the effect size, the greater the height difference between men and women will be.  Statistic effect size helps us in determining if the difference is real or if it is due to a change of factors.
#
# In simple terms , an effect size of **0.2** corresponds to the difference between the **heights of 15 year old and 16 year old** girls in the US. A **0.5** effect size corresponds to the difference between the **heights of 14 year old and 18 year old girls.** An effect size of **0.8** equates to the difference between the **heights of 13 year old and 18 year old girls.**
#
#
# Therefore, a significant effect does not necessarily mean a big effect.
# Also, if the sample size is large enough, any treatment effect, no matter how small, can be enough for us to reject the null hypothesis.
#
# To know more about the effect size, refer to the following link :
#
# https://www.leeds.ac.uk/educol/documents/00002182.htm
#
# ## Power of a test :
# The **power** of a test is the probability of rejecting the null hypothesis when it is false; in other words, it is the probability of avoiding a type II error.
#
# Power of a test= 1- P(Type II error).
#
# **Why is it important?**
#
# To find the sample size needed to get an effect of a certain size. This is probably the most common use for power analysis–it tells you how many samples/trials you need to do to avoid incorrectly rejecting the null hypothesis.**We need to determine the power of a test to ensure that the sample size that we are taking is enough to support our statistical hypothesis.**
#
#
# **Therefore it is important to consider power and effect size in hypothesis testing**

# %% [markdown]
# ## Level of significance
#
# We have already talked about the significance level (α), is a measure of the strength of the evidence that must be present in your sample before you will reject the null hypothesis and conclude that the effect is statistically significant.
#
# **Level of significance is 5%**
#
# **A significance level of 0.05 indicates a 5% risk of concluding that a difference exists when there is no actual difference.**
# Or we can say that our analysis has a 5% chance of producing a significant result when the null hypothesis is correct.A significance level of 0.05 is the most common. However, it’s the analyst’s responsibility to determine how much evidence to require for concluding that an effect exists.
#
# We can increase or decrease the level of significance according to our testing problem.
#
#
# ## p- value :
# It is the level of significance at which we reject our null hypothesis.
#
# *The term significance level (alpha) is used to refer to a pre-chosen probability and the term "P value" is used to indicate a probability that you calculate after a given study.*
#
# **If the p-value is less than the significance level, we can reject the null hypothesis and conclude that the effect is statistically significant. **
#
# **How Do You Interpret P values?**
#
# **High P-values:**  Your test results on the sample population are consistent with a null hypothesis.
#
# **Low P-values:**  Your test results on the sample population are not consistent with a null hypothesis.
#
# For example, suppose that a vaccine study produced a P value of 0.04. This P value indicates that if the vaccine had no effect, you’d obtain the observed difference or more in 4% of studies due to random sampling error.
#
# P values address only one question: how likely are your data, assuming a true null hypothesis?**It does not measure support for the alternative hypothesis.**
#
# **Correct:** Assuming that the vaccine had no effect, you’d obtain the observed difference or more in 4% of studies due to random sampling error.
#
# **Incorrect:** If you reject the null hypothesis, there’s a 4% chance that you’re making a mistake.

# %% [markdown]
# # Critical regions :
#
# The critical region is the region of values that corresponds to the rejection
# of the null hypothesis at some chosen probability level.
#
# **One tailed test** : A test of a statistical hypothesis , where the region of rejection is on only one side of the sampling distribution , is called a one-tailed test.
#
# **Two-tailed test** : A two-tailed test is a statistical test in which the critical area of a distribution is two-sided and tests whether a sample is greater than or less than a certain range of values. If the sample being tested falls into either of the critical areas, the alternative hypothesis is accepted instead of the null hypothesis.

# %%
im3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=631x521 at 0x22DE0253E80>

# %%
im5
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=625x518 at 0x22DE0267B38>

# %%
im4
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=611x523 at 0x22DE7D77198>

# %% [markdown]
# # Basic steps in a hypothesis testing :
#
# #### 1.Choosing an appropriate test statistic.
#
# #### 2.Defining a null hypothesis and accordingly an alternative hypothesis.
#
# #### 3.Computing a p-value.
#
# #### 4.Interpreting the results.

# %%
im6
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x422 at 0x22DE0253F98>

# %% [markdown]
# ### Parametric tests :
#
# Parametric tests assume underlying statistical distributions in the data. Therefore, several conditions of validity must be met so that the result of a parametric test is reliable.
#
# ### Non parametric tests :
#
# Nonparametric tests do not rely on any distribution. They can thus be applied even if parametric conditions of validity are not met.

# %% [markdown]
# # Parametric tests

# %% [markdown]
# # For all our tests, we will be using a significance level of 0.05.

# %% [markdown]
# # T-test
#
# **Assupmtions :**
#
# - Observations in each sample are independent and identically distributed (iid).
#
# - Observations in each sample are normally distributed.

# %% [markdown]
# ## One Sample T-test
#
# A One Sample T-Test is a statistical test used to evaluate the null hypothesis that the mean μ0 of a sample dataset of independant observations is equal to the true mean μ of the population from which the data is sampled.
#
# H0: μ = μ0
#
# H1: μ ≠ μ0

# %%
im9
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x384 at 0x22DE7D0AF28>

# %%
# Example of one sample t-test
import numpy as np
from scipy.stats import ttest_1samp

data1 = np.random.normal(0, 1, size=20)
μ0=0
print(np.mean(data1))

stat, p = ttest_1samp(data1,μ0)

print('stat=%.3f, p=%.3f' % (stat, p))

if p > 0.05:
    print('We fail to reject our null hypotheis')
else:
    print('We rejct the null hypothesis')
# Out:
# -0.026286001470461583
# stat=-0.152, p=0.881
# We fail to reject our null hypotheis

# %% [markdown]
# ## Two sample T-test
#
# H0:  μ1 = μ2(The means of the samples are equal).
#
# H1:  μ1 ≠ μ2(The means of the samples are unequal).

# %%
# Example of two tailed Student's t-test 


data1 = np.random.normal(0, 1, size=20)
data2 = np.random.normal(2, 1, size=20)

print(np.mean(data1))
print(np.mean(data2))
print(np.mean(data1)-np.mean(data2))
# Out:
# -0.30562666182390125
# 1.6324008785722146
# -1.9380275403961158

# %%
from scipy.stats import ttest_ind
stat, p = ttest_ind(data1,data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('We fail to reject our null hypotheis')
else:
    print('We rejct the null hypothesis')
# Out:
# stat=-5.676, p=0.000
# We rejct the null hypothesis

# %% [markdown]
# ## Two sample t-test can be applied when we have same sample size as well as for different sample sizes also.

# %%
im10
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x257 at 0x22DE8CD6E80>

# %%
# Example of two tailed Student's t-test with same sample size
from scipy.stats import ttest_ind

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]

data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same mean')
else:
    print('Probably different means')
# Out:
# stat=-0.326, p=0.748
# Probably the same mean

# %%
# Example of two tailed Student's t-test 
from scipy.stats import ttest_ind

data1 = np.random.normal(0, 4, size=20)
data2 = np.random.normal(2, 5, size=20)

print(np.mean(data1))
print(np.mean(data2))
print(np.mean(data1)-np.mean(data2))
# Out:
# 0.3196450192887993
# 2.926442828104947
# -2.6067978088161476

# %%
stat, p = ttest_ind(data1,data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('We fail to reject our null hypotheis')
else:
    print('We rejct the null hypothesis')
# Out:
# stat=-2.499, p=0.017
# We rejct the null hypothesis

# %%
im12
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=456x238 at 0x22DE7D59C50>

# %%
# Example of  two tailed Student's t-test with different sample size
from scipy.stats import ttest_ind

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169,0.134,-1,234]

stat, p = ttest_ind(data1, data2)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same mean')
else:
    print('Probably different distributions')
# Out:
# stat=-0.878, p=0.390
# Probably the same mean

# %%
# Example of two tailed Student's t-test 
from scipy.stats import ttest_ind

data1 = np.random.normal(0, 4, size=40)
data2 = np.random.normal(2, 5, size=20)

print(np.mean(data1))
print(np.mean(data2))
print(np.mean(data1)-np.mean(data2))
# Out:
# -0.38664769506085034
# 3.4894860963476524
# -3.8761337914085026

# %%
stat, p = ttest_ind(data1,data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('We fail to reject our null hypotheis')
else:
    print('We rejct the null hypothesis')
# Out:
# stat=-3.308, p=0.002
# We rejct the null hypothesis

# %% [markdown]
#  ### When to use an unpaired t-test?
#
# **An unpaired t-test is used to compare the mean between two independent groups. You use an unpaired t-test when you are comparing two separate groups with equal variance.**
#
# Examples of appropriate instances during which to use an unpaired t-test:
#
# ● Research, such as a pharmaceutical study or other treatment plan, where ½ of the subjects are assigned to the treatment group and ½ of the subjects are randomly assigned to the control group.
#
# ● Research during which there are two independent groups, such as women and men, that examines whether the average bone density is significantly different between the two groups.
#
# ● Comparing the average commuting distance traveled by New York City and San Francisco residents using 1,000 randomly selected participants from each city.

# %% [markdown]
# ## Paired Student’s t-test
#
# Also known as a dependent or correlated t-test tests whether the means of two paired samples are significantly different.
#
# H0: μ1 = μ2(the means of the samples are equal).
#
# H1: μ1 ≠ μ2(the means of the samples are unequal).
#
#
#
#
#
# ### When to use a paired t-test?
#
# **Paired t-tests are used when the same item or group is tested twice, which is known as a repeated measures t-test. Some examples of instances for which a paired t-test is appropriate include:**
#
# ● The before and after effect of a pharmaceutical treatment on the same group of people.
#
# ● Body temperature using two different thermometers on the same group of participants.
#
# ● Standardized test results of a group of students before and after a study prep course.

# %%
 im11
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=942x157 at 0x22DE7D17F28>

# %%
# Example of two-tailed Paired Student's t-test
from scipy.stats import ttest_rel

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

stat, p = ttest_rel(data1, data2)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
        print('Probably the same distribution')
else:
        print('Probably different distributions')
# Out:
# stat=-0.334, p=0.746
# Probably the same distribution

# %% [markdown]
# ### Paired vs unpaired t-test
#
# **The key differences between a paired and unpaired t-test are summarized below:**
#
# ● A paired t-test is designed to compare the means of the same group or item under two separate scenarios. An unpaired t-test compares the means of two independent or unrelated groups.
#
# ● In an unpaired t-test, the variance between groups is assumed to be equal. In a paired t-test, the variance is not assumed to be equal.

# %% [markdown]
# ## One sample Z-test
# A One Sample Z-Test is a statistical test used to evaluate the null hypothesis that the mean μ0 of a **large sample** dataset of independant observations is equal to the true mean μ of the population from which the data is sampled and the **population variance is known.**
#
# H0: μ = μ0
#
# H1: μ ≠ μ0

# %%
im13
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=231x219 at 0x22DE7D1FAC8>

# %%
# Example of one tailed Z-test

from scipy import stats
from statsmodels.stats import weightstats as stests

data1 = np.random.normal(0, 1, size=100)


pval1 = stests.ztest(data1, x2=None, value=0,alternative='two-sided')

print(float(pval1))

if pval1>0.05:
    print("accept null hypothesis")
else:
    print("reject null hypothesis")
# Out:
# 0.7054476316032563
# accept null hypothesis

# %% [markdown]
# ## Two sample Z-test

# %%
im14
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=389x129 at 0x22DE7D3AA90>

# %%
# Example of two tailed Z-test

from scipy import stats
from statsmodels.stats import weightstats as stests

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]

data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

ztest ,pval1 = stests.ztest(data1, x2=data2,alternative='two-sided')
print(float(pval1))

if pval1>0.05:
    print("accept null hypothesis")
else:
    print("reject null hypothesis")
# Out:
# 0.7447151860755614
# accept null hypothesis

# %% [markdown]
# ## T-test Vs Z-test :
# It is generally confusing to decide which test to use in which situations.
#
# **T-tests are applied when :**
#
# ● Sample Size is small(But it should not be less than 5).
#
# ● Population variance is not known.
#
# **Z-tests are applied when :**
#
# ● Sample Size is large(Generally, a sample size exceeding 30 sample units is regarded as large).
#
# ● Population variance is known.

# %% [markdown]
# ## F-test
#
#  F-test is statistical test, that determines the equality of the variances of the two normal populations.
#
#  **Assumptions** :
#
# -The population is normally distributed.
#
# -Samples have been drawn randomly.
#
# -Observations are independent.
#
#
# **F = σ1^2/σ2^2**
#
# where σ1^2 and σ2^2 are the variances.
#
# H0:  σ1^2 = σ2^2
#
# H1:  σ1^2 ≠ σ2^2

# %%
from scipy.stats import bartlett

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]

data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

test ,pval1 = scipy.stats.bartlett(data1, data2)
print(float(pval1))

if pval1>0.05:
    print("accept null hypothesis")
else:
    print("reject null hypothesis")
# Out:
# 0.1112558884735158
# accept null hypothesis

# %% [markdown]
# ## F-test vs T-test
#
# 1.A hypothesis test that is applied when the standard deviation is not known and the sample size is small is t-test. On the other hand, a statistical test, which determines the equality of the variances of the two normal datasets, is known as f-test.
#
# 2.The t-test is used to compare the means of two populations. In contrast, f-test is used to compare two population variances.

# %% [markdown]
# ## Analysis of Variance Test (ANOVA)
#
# ANOVA is a statistical technique that is used to compare the means of more than two populations.
#
# H0: the means of the samples are equal.
#
# H1: one or more of the means of the samples are unequal.
#
# **Assumptions**
#
# -Observations in each sample are independent and identically distributed (iid).
#
# -Observations in each sample are normally distributed.
#
# -Observations in each sample have the same variance.

# %%
im8
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=595x141 at 0x22DE89F2B00>

# %% [markdown]
# #####  where
#
# k = the number of treatments or independent comparison groups
#
# N = total number of observations or total sample size.
#
#
# **Grand Mean**
#
# grand mean of a set of samples is the total of all the data values divided by the total sample size.
#
# **Total Variation**
#
# The total variation (not variance) is comprised the sum of the squares of the differences of each mean with the grand mean.
#
# **Between Group Variation**
#
# The variation due to the interaction between the samples is denoted SS(B) for Sum of Squares Between groups.
#
# **Within Group Variation**
#
# The variation due to differences within individual samples, denoted SS(W) for Sum of Squares Within groups.

# %%
# Example of the Analysis of Variance Test
from scipy.stats import f_oneway

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
data3 = [-0.208, 0.696, 0.928, -1.148, -0.213, 0.229, 0.137, 0.269, -0.870, -1.204]

stat, p = f_oneway(data1, data2, data3)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same mean')
else:
    print('Probably different means')
# Out:
# stat=0.096, p=0.908
# Probably the same mean

# %%
# Example of two tailed Student's t-test with same sample size
from scipy.stats import ttest_ind

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]

data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

stat, p = ttest_ind(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same mean')
else:
    print('Probably different means')
# Out:
# stat=-0.326, p=0.748
# Probably the same mean

# %%
# Example of two tailed Student's t-test with same sample size using Anova
from scipy.stats import f_oneway
import pandas as pd
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]

data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
import numpy as np
print(np.mean(data1))

print(np.mean(data2))

stat, p = f_oneway(data1, data2)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same mean')
else:
    print('Probably different means')
# Out:
# -0.32489999999999997
# -0.15209999999999996
# stat=0.106, p=0.748
# Probably the same mean

# %% [markdown]
# ### T-test vs ANOVA
#
#  These two tests are based on the common assumption like the population from which sample is drawn should be normally distributed, homogeneity of variance, random sampling of data, independence of observations, measurement of the dependent variable on the ratio or interval level, people often misinterpret these two.The key difference is that **T-test is a special type of ANOVA that can be used when we have only two populations to compare their means.**

# %% [markdown]
# ## Analysis of Covariance(ANCOVA)
#
# ANCOVA is a blend of analysis of variance (ANOVA) and regression. It is similar to factorial ANOVA, in that it can tell you what additional information you can get by considering one independent variable (factor) at a time, without the influence of the others. It takes **covariance** into consideration.
#
# **Assumptions**
#
# -The residuals (error terms) should be normally distributed.
#
# -The errors should be independent.

# %% [markdown]
# #### Key Differences Between ANOVA and ANCOVA :
#
# 1. A covariate is not taken into account, in ANOVA, but considered in ANCOVA.
#
#
# 2. ANOVA characterises between group variations, exclusively to treatment. In contrast, ANCOVA divides between group variations to treatment and covariate.
#
#
# 3. ANOVA exhibits within group variations, particularly to individual differences. Unlike ANCOVA, that bifurcates within group variance in individual differences and covariate.

# %% [markdown]
# ### Multivariate Analysis of Variance( MANOVA)
#
# A MANOVA is an ANOVA with two or more continuous response variables.
#
# ### Multiple Analysis of Covariance (MANCOVA)
#
#  A MANOVA can include only factors, an analysis evolves from MANOVA to MANCOVA when one or more more covariates are added to the mix.
#
#  http://www.statsmakemecry.com/smmctheblog/stats-soup-anova-ancova-manova-mancova

# %% [markdown]
# # Non parametric tests

# %% [markdown]
# ## Wilcoxon Signed rank test

# %% [markdown]
# ## One-sample
#
# **One sample Wilcoxon non parametric hypothesis test is a rank based test and it compares the standard value (theoretical value) with hypothesized median.**
#
#
# -Identify the difference between each individual value and the median
#
# -If the difference of individual value and median is zero, ignore it.
#
# -Ignore the signs of the difference values and assign lowest rank to the smallest difference value. If the values have tied, then consider the mean value.
#
# -Compute the sum of ranks of positive difference values, and negative difference values (W+ and W-)
#
# -Then we Calculate the test statistics and Compare the test statistic, W, with the critical value in the tables; the null hypothesis can be rejected if W is less than or equal to the critical value.
#
#
#
#
#
#
# PARAMETRIC ALTERNATIVE : One-sample Z-test, One sample t-test
#
# With this test, you also estimate the population median and compare it to a reference/target value.

# %%
import scipy.stats as stats
import numpy as np

# generate the data

normDist = stats.norm(loc=7.5, scale=3)
data = normDist.rvs(100)

# Define a value to check against
checkVal = 6.5
print(np.median(data))

pVal = stats.wilcoxon(data-checkVal)
print(pVal)

if pVal > 0.05:
    print('Probably the same median')
else:
    print('Probably different medians')
# Out:
# 6.841448906691147
# 0.13473933100822336
# Probably the same median

# %% [markdown]
# ## Two sample
#
# Tests if the medians of two samples are equal.
#
# Parametric Alternative : paired t-test

# %%
from scipy.stats import wilcoxon

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

stat, p = wilcoxon(data1, data2)

print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same median')
else:
    print('Probably different medians')
# Out:
# stat=21.000, p=0.508
# Probably the same median

# %% [markdown]
# ## Mann-Whitney U Test
#
#    Alternative parametric test : One way ANOVA, two sample t-test.
#
#    Tests whether the distributions of two independent samples are equal or not.
#
#    H0: the distributions of both samples are equal.
#
#    H1: the distributions of both samples are not equal.
#
#   **Assumptions**
#
#    -Observations in each sample are independent and identically distributed (iid).
#
#    -Observations in each sample can be ranked.

# %%
# Example of the Mann-Whitney U Test
from scipy.stats import mannwhitneyu

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]

stat, p = mannwhitneyu(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=40.000, p=0.236
# Probably the same distribution

# %% [markdown]
# #### NOTE :
#
# The Wilcoxon signed rank test is used in similar situations as the Mann-Whitney U-test.The main difference is that the Mann-Whitney U-test tests two independent samples, whereas the Wilcox sign test tests two dependent samples.

# %% [markdown]
# ## Kruskal-Wallis H Test
#
#   Parametric alternative : 	One-way ANOVA
#
#   Tests whether the distributions of **two or more** independent samples are equal or not.
#
#    H0: the distributions of all samples are equal.
#
#    H1: the distributions of one or more samples are not equal.
#
#  **Assumptions**
#
#    -Observations in each sample are independent and identically distributed (iid).
#
#    -Observations in each sample can be ranked.

# %%
# Example of the Kruskal-Wallis H Test
from scipy.stats import kruskal

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
data3 = [-0.208, 0.696, 0.928, -1.148, -0.213, 0.229, 0.137, 0.269, -0.870, -1.204]

stat, p = kruskal(data1, data2,data3)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably the same distribution')
else:
    print('Probably different distributions')
# Out:
# stat=0.854, p=0.652
# Probably the same distribution

# %% [markdown]
# # Correlation Tests
#
# This section lists statistical tests that you can use to check if two samples are related.

# %% [markdown]
# ## Pearson’s Correlation Coefficient
#
# Tests whether two samples have a linear relationship.
#
# H0: the two samples are independent.
#
# H1: there is a dependency between the samples.
#
# **Assumptions**
#
# -Observations in each sample are independent and identically distributed (iid).
#
# -Observations in each sample are normally distributed.
#
# -Observations in each sample have the same variance.

# %%
# Example of the Pearson's Correlation test
from scipy.stats import pearsonr

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]

stat, p = pearsonr(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably independent')
else:
    print('Probably dependent')
# Out:
# stat=0.688, p=0.028
# Probably dependent

# %% [markdown]
# ## Spearman’s Rank Correlation
#
#  Tests whether two samples have a monotonic relationship.
#
#  H0: the two samples are independent.
#  H1: there is a dependency between the samples.
#
# **Assumptions**
#
# -Observations in each sample are independent and identically distributed (iid).
#
# -Observations in each sample can be ranked.

# %%
# Example of the Spearman's Rank Correlation Test
from scipy.stats import spearmanr

data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]

stat, p = spearmanr(data1, data2)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably independent')
else:
    print('Probably dependent')
# Out:
# stat=0.855, p=0.002
# Probably dependent

# %% [markdown]
# ## Chi-Squared Test
#
# Tests whether two categorical variables are related or independent.
#
#  H0: the two samples are independent.
#
#  H1: there is a dependency between the samples.
#
#  **Assumptions**
#
# -Observations used in the calculation of the contingency table are independent.

# %%
# Example of the Chi-Squared Test
from scipy.stats import chi2_contingency

table = [[209,280],[225,248]]

stat, p, dof, expected = chi2_contingency(table)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probably independent')
else:
    print('Probably dependent')
# Out:
# stat=2.073, p=0.150
# Probably independent

# %% [markdown]
# **Example:** "Which holiday do you prefer?"

# %%
im7
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=372x119 at 0x22DE7D1FD68>

# %% [markdown]
# **Does Gender affect Preferred Holiday?**
#
# **If Gender (Man or Woman) does affect Preferred Holiday we say they are dependent.**
#
# p value is 0.15
#
#
#
# Since p-value  is greater than 0.05, so we believe the variables are independent (ie not linked together).
#
# **In other words Men and Women probably do not have a different preference for Beach Holidays or Cruises.**
